# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('C:/Users/Sergio/Desktop/CIencia de datos/Trabajo final/Student_performance_data _.csv')
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.shape
# Out:
# (2392, 15)

# %%
matriz_correla = df.corr()
print(matriz_correla)
# Out:
#                    StudentID       Age    Gender  Ethnicity  \
# StudentID           1.000000 -0.042255 -0.014625  -0.012990
# Age                -0.042255  1.000000  0.044895  -0.028473
# Gender             -0.014625  0.044895  1.000000   0.016010
# Ethnicity          -0.012990 -0.028473  0.016010   1.000000
# ParentalEducation  -0.002307  0.025099  0.006771   0.033595
# StudyTimeWeekly     0.026976 -0.006800  0.011469   0.007184
# Absences            0.014841 -0.011511  0.021479  -0.025712
# Tutoring           -0.007834 -0.012076 -0.031597  -0.017440
# ParentalSupport     0.003016  0.033197  0.008065   0.020922
# Extracurricular    -0.003611 -0.025061 -0.005964  -0.008927
# Sports             -0.020703 -0.046320 -0.008897  -0.004484
# Music              -0.005468 -0.003492  0.007109  -0.014627
# Volunteering        0.008011  0.013074 -0.000200   0.013468
# GPA                -0.002697  0.000275 -0.013360   0.027760
# GradeClass         -0.098500 -0.006250  0.022998  -0.023326
#
# ...

# %%
plt.figure(figsize=(15, 8)) 
sns.heatmap(matriz_correla, annot=True, cmap='coolwarm', linewidths=0.2)
plt.title('Matriz de Correlación')
plt.show()

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round(2)
# Out:
#        StudentID      Age   Gender  Ethnicity  ParentalEducation  \
# count    2392.00  2392.00  2392.00    2392.00            2392.00
# mean     2196.50    16.47     0.51       0.88               1.75
# std       690.66     1.12     0.50       1.03               1.00
# min      1001.00    15.00     0.00       0.00               0.00
# 25%      1598.75    15.00     0.00       0.00               1.00
# 50%      2196.50    16.00     1.00       0.00               2.00
# 75%      2794.25    17.00     1.00       2.00               2.00
# max      3392.00    18.00     1.00       3.00               4.00
#
#        StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# count          2392.00   2392.00   2392.00          2392.00          2392.00
# mean              9.77     14.54      0.30             2.12             0.38
# std               5.65      8.47      0.46             1.12             0.49
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.scatterplot(x=df.GPA, y= df['Absences'])
plt.title('Relacion entre Precio apertura y cierre')
plt.xlabel('GPA')
plt.ylabel('Parental Support')
# Out:
# Text(0, 0.5, 'Parental Support')

# %%
sns.histplot(data=df, x="GPA",bins=10)
# Out:
# <Axes: xlabel='GPA', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df.GPA, y= df.Tutoring, hue=df.GPA)
plt.title('Boxplot comparativo Genero vs Tarifa')
plt.xlabel('Genero')
plt.ylabel('Tarifa')
# Out:
# Text(0, 0.5, 'Tarifa')
